# %% [markdown]
# <a href="https://colab.research.google.com/github/r-ogrady/demos_vis_geospatial/blob/main/c12_train_MNIST_noise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notes
# * **Purpose:** train MNIST data with noisy data, different lrs

# %%
import numpy as np
import time
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import copy
import random
from google.colab import drive
import sys
from torchvision import datasets
import torchvision.transforms as T
import torchvision.transforms.functional as F
import torch.nn as nn
import torch
import torch.optim as optim
from torch.utils.data import TensorDataset, Dataset, DataLoader
from torchsummary import summary

# %% [markdown]
# # Mount drive

# %%
# in colab - mount drive
drive.mount('/content/drive/')
# %cd '/content/drive/My Drive/Dissertation/code'
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/Dissertation/code

# %%
sys.path.append("drive/My Drive/Dissertation/code")
from b01_cpl import CorrelationPenaltyLoss
from b02_models import LeNet5
from b03_plotters import plotter0, plotter, plotter_corr

# %% [markdown]
# # Helper functions and initialisations
# For training, plotting training metrics and checking accuracy on test set

# %%
# random seeds
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
generator1=torch.Generator().manual_seed(42)

# %%
# for polotting
def unnormalise(img):
    mean = 0.1307
    std = 0.3081
    img = img * std + mean
    return torch.clamp(img, 0, 1)

# %%
# trainer with my loss
def trainer0(n_epochs,lrs,train_dataloader,val_dataloader):

    # storage
    # data dict for storing metrics per lr and epoch
    epoch_keys=["train_losses","train_accuracies",
                "val_losses","val_accuracies","time"]
    data_dict={lr:
      {key:[] for key in epoch_keys} for lr in lrs}
    # storing models
    models = []

    # we train a new model for each lr value
    for i,lr in enumerate(lrs):
        # load model for each loop
        model = LeNet5().to(device)
        optimizer = optim.Adam(params = model.parameters(),lr=lr)
        criterion = nn.CrossEntropyLoss()

        # initialise variables for EarlyStopping
        best_loss = float('inf')
        best_model_weights = None
        patience = 10


        print(f"training for lr = {lr}")

        for epoch in range(n_epochs):
            t0 = time.time()
            # initialise variables for recording training loss and accuracy
            running_loss = 0.0
            running_loss_base = 0.0
            running_correct = 0
            running_total = 0

            model.train()
            for input,labels in train_dataloader:
                desired_labels=labels[0]

                input = input.to(device)
                desired_labels = desired_labels.to(device)


                optimizer.zero_grad()
                output = model(input)
                loss = criterion(output,desired_labels)
                loss.backward()
                optimizer.step()

                # training loss and accuracy for batch
                # this is scaled by the batch size and divided back later
                running_loss += loss.item() * input.size(0)

                _, predicted = torch.max(output.data, 1)
                running_total += desired_labels.size(0)
                running_correct += (predicted == desired_labels).sum().item()

            # training loss and accuracy for epoch (scaled back)
            train_loss = running_loss/len(train_dataloader.dataset)

            train_accuracy = 100 * running_correct/running_total

            # store
            epoch_dict=data_dict[lr]
            epoch_dict["train_losses"].append(train_loss)

            epoch_dict["train_accuracies"].append(train_accuracy)

            # initialise variables for recording val loss and accuracy
            val_running_loss = 0.0
            val_running_correct = 0
            val_running_total = 0

            model.eval()
            with torch.no_grad():
                for input,labels in val_dataloader:
                    desired_labels=labels[0]
                    orthog_labels=labels[1]
                    input = input.to(device)
                    desired_labels = desired_labels.to(device)
                    orthog_labels = orthog_labels.to(device)

                    output = model(input)

                    # validation loss and accuracy for batch
                    val_running_loss += criterion(output,desired_labels).item() * desired_labels.size(0)

                    _, predicted = torch.max(output.data, 1)
                    val_running_total += desired_labels.size(0)
                    val_running_correct += (predicted == desired_labels).sum().item()


            # validation loss and accuracy for epoch
            val_loss = val_running_loss / len(val_dataloader.dataset)

            val_accuracy = 100 * val_running_correct / val_running_total

            # store
            epoch_time=time.time()-t0
            epoch_dict["val_losses"].append(val_loss)

            epoch_dict["val_accuracies"].append(val_accuracy)
            epoch_dict["time"].append(epoch_time)

            # print for epoch
            if epoch % 5 == 0:
                print(f"epoch: {epoch + 1}, time: {epoch_time:0.2f}")
                print("training loss: ",
                      f"{train_loss:0.2f}, accuracy: {train_accuracy:.2f}")
                print("validation loss: ",
                      f"{val_loss:0.2f}, accuracy: {val_accuracy:.2f}")
                print()

            # EarlyStopping
            if val_loss < best_loss:
                best_loss = val_loss
                best_model_weights = copy.deepcopy(model.state_dict())
                patience = 10
            else:
                patience -= 1
                if patience == 0:
                    print(f"Early stop at epoch {epoch+1}\n")
                    break

        # load and store the best model weights
        model.load_state_dict(best_model_weights)
        models.append(model)

    return data_dict, models

# %%
def trainer(n_epochs, lrs, alphas, layer_type, train_dataloader, val_dataloader):

    # storage
    # data dict for storing metrics per alpha and epoch
    epoch_keys = ["train_losses_base", "train_losses_corr", "train_losses", "train_accuracies",
                  "val_losses_base", "val_losses_corr", "val_losses", "val_accuracies", "time"]

    # storing models
    models = [[] for _ in lrs]

    # we train a new batch of models for each lr
    lr_dict = {}
    for i, lr in enumerate(lrs):
        print(f"training for lr = {lr}")

        # Create a new alpha_dict for each lr
        alpha_dict = {alpha: {key: [] for key in epoch_keys} for alpha in alphas}

        # we train a new model for each alpha value
        for alpha in alphas:
            # load model for each loop
            model = LeNet5().to(device)
            optimizer = optim.Adam(params=model.parameters(), lr=lr)
            criterion = CorrelationPenaltyLoss(model=model,
                                               base_loss_fn=base_loss_fn,
                                               layer_type=layer_type,
                                               alpha=alpha)

            # initialise variables for EarlyStopping
            best_loss = float('inf')
            best_model_weights = None
            patience = 10

            print(f"training for alpha = {alpha}")

            for epoch in range(n_epochs):
                t0 = time.time()
                # initialise variables for recording training loss and accuracy
                running_loss = 0.0
                running_loss_base = 0.0
                running_correct = 0
                running_total = 0

                model.train()
                for input, labels in train_dataloader:
                    desired_labels = labels[0]
                    orthog_labels = labels[1]
                    input = input.to(device)
                    desired_labels = desired_labels.to(device)
                    orthog_labels = orthog_labels.to(device)

                    optimizer.zero_grad()
                    output = model(input)
                    loss = criterion(output, desired_labels, orthog_labels)
                    loss_base = base_loss_fn(output, desired_labels)
                    loss.backward()
                    optimizer.step()

                    # training loss and accuracy for batch
                    # this is scaled by the batch size and divided back later
                    running_loss += loss.item() * input.size(0)
                    running_loss_base += loss_base.item() * input.size(0)
                    _, predicted = torch.max(output.data, 1)
                    running_total += desired_labels.size(0)
                    running_correct += (predicted == desired_labels).sum().item()

                # training loss and accuracy for epoch (scaled back)
                train_loss = running_loss / len(train_dataloader.dataset)
                train_loss_base = running_loss_base / len(train_dataloader.dataset)
                train_loss_corr = (train_loss - train_loss_base) / alpha
                train_accuracy = 100 * running_correct / running_total

                # store
                epoch_dict = alpha_dict[alpha]
                epoch_dict["train_losses"].append(train_loss)
                epoch_dict["train_losses_corr"].append(train_loss_corr)
                epoch_dict["train_losses_base"].append(train_loss_base)
                epoch_dict["train_accuracies"].append(train_accuracy)

                # initialise variables for recording val loss and accuracy
                val_running_loss = 0.0
                val_running_loss_base = 0.0
                val_running_correct = 0
                val_running_total = 0

                model.eval()
                with torch.no_grad():
                    for input, labels in val_dataloader:
                        desired_labels = labels[0]
                        orthog_labels = labels[1]
                        input = input.to(device)
                        desired_labels = desired_labels.to(device)
                        orthog_labels = orthog_labels.to(device)

                        output = model(input)

                        # validation loss and accuracy for batch
                        val_running_loss += criterion(output, desired_labels, orthog_labels).item() * desired_labels.size(0)
                        val_running_loss_base += base_loss_fn(output, desired_labels).item() * desired_labels.size(0)
                        _, predicted = torch.max(output.data, 1)
                        val_running_total += desired_labels.size(0)
                        val_running_correct += (predicted == desired_labels).sum().item()

                # validation loss and accuracy for epoch
                val_loss = val_running_loss / len(val_dataloader.dataset)
                val_loss_base = val_running_loss_base / len(val_dataloader.dataset)
                val_loss_corr = (val_loss - val_loss_base) / alpha
                val_accuracy = 100 * val_running_correct / val_running_total

                # store
                epoch_time = time.time() - t0
                epoch_dict["val_losses"].append(val_loss)
                epoch_dict["val_losses_corr"].append(val_loss_corr)
                epoch_dict["val_losses_base"].append(val_loss_base)
                epoch_dict["val_accuracies"].append(val_accuracy)
                epoch_dict["time"].append(epoch_time)

                # print for epoch
                if epoch % 5 == 0:
                    print(f"epoch: {epoch + 1}, time: {epoch_time:0.2f}")
                    print("training loss (base/corr/combo): ",
                          f"{train_loss_base:0.2f}/{train_loss_corr:0.2f}/{train_loss:0.2f}, accuracy: {train_accuracy:.2f}")
                    print("validation loss (base/corr/combo): ",
                          f"{val_loss_base:0.2f}/{val_loss_corr:0.2f}/{val_loss:0.2f}, accuracy: {val_accuracy:.2f}")
                    print()

                # EarlyStopping
                if val_loss < best_loss:
                    best_loss = val_loss
                    best_model_weights = copy.deepcopy(model.state_dict())
                    patience = 10
                else:
                    patience -= 1
                    if patience == 0:
                        print(f"Early stop at epoch {epoch + 1}\n")
                        break

            # load and store the best model weights
            model.load_state_dict(best_model_weights)
            models[i].append(model)

        # Store the alpha_dict for this lr
        lr_dict[lr] = alpha_dict

    return lr_dict, models

# %%
# test accuracy of a given model
def tester(models,alphas,test_dataloader,test_type):

    # for storing
    accuracies = torch.zeros(len(models))

    for i,model in enumerate(models):
        num_correct = 0
        num_samples = 0
        model.eval()

        with torch.no_grad():
            if test_type=="raw":
                for input,target in test_dataloader:
                    input,target = input.to(device),target.to(device)
                    scores = model(input)
                    _, predictions = scores.max(1)
                    num_correct +=  (predictions ==  target).sum()
                    num_samples +=  predictions.size(0)
            elif test_type=="cpl":
                for input,target in test_dataloader:
                    target=target[0]
                    input,target = input.to(device),target.to(device)
                    scores = model(input)
                    _, predictions = scores.max(1)
                    num_correct +=  (predictions ==  target).sum()
                    num_samples +=  predictions.size(0)


        accuracy = float(num_correct)/float(num_samples)*100
        accuracies[i] = accuracy

        print(f"Alpha = {alphas[i]} Model:")
        print(f'Got {num_correct}/{num_samples} with accuracy {accuracy:.2f}\n')

    return accuracies

# %% [markdown]
# # Load data

# %%
# NOTE non-deterministic parts here!

# first we extend the class for the dataset to include the transformation in the getitem call
class AddGaussianNoise(object):
    def __init__(self, mean=0., std=1.):
        self.std = std
        self.mean = mean

    def __call__(self, tensor):
        return tensor + torch.randn(tensor.size()) * self.std + self.mean

    def __repr__(self):
        return self.__class__.__name__ + '(mean={0}, std={1})'.format(self.mean, self.std)

class MyMNIST(Dataset):
    def __init__(self, root, train=True, transform=None, download=True):
        self.mnist = datasets.MNIST(root=root, train=train, download=download)
        self.transform = transform

    def __len__(self):
        return len(self.mnist)

    def __getitem__(self, index):
        img, label = self.mnist[index]

        # implement the transforms in correct order
        # resize and convert to tensor first
        img = T.Resize((32, 32))(img)
        img = T.ToTensor()(img)

        # randomly apply gaussian noise with a given sigma
        noise_sigmas=np.arange(0,0.6,0.1)
        noise_sigma=random.choice(noise_sigmas)
        add_noise=AddGaussianNoise(mean=0,std=noise_sigma)
        new_label=noise_sigma
        img = add_noise(img)

        # normalise after noise/blur has been applied
        img = T.Normalize((0.1307,), (0.3081,))(img)

        # apply additional transformations
        if self.transform:
            img = self.transform(img)

        return img, (label, new_label)

# create noise dataset
noise_dataset=MyMNIST(
    root='./data',
    train=False)

# w/o my orthogonal transform
# import train/test data without orthogonal_action
transform=T.Compose([T.Resize((32,32)),
                    T.ToTensor(),
                    T.Normalize((0.1307,), (0.3081,))
                    ])

raw_test_dataset=datasets.MNIST(
    root='./data/',
    train=False,
    download=True,
    transform=transform)

# %%
fig,axs=plt.subplots(1,3, constrained_layout=True)
for i in range(3):
    item=noise_dataset[i]
    img=item[0]
    img=unnormalise(img)
    axs[i].imshow(item[0].squeeze())
    axs[i].set_title(f'number {item[1][0]}\nnoise sd = {item[1][1]:0.1f}')
fig.suptitle("Noise",y=0.85)
# Out:
# Text(0.5, 0.85, 'Noise')

# %%
# validation split
noise_train_dataset,noise_val_dataset=torch.utils.data.random_split(noise_dataset,[5/6, 1/6],generator=generator1)

# dataloader
noise_train_dataloader = DataLoader(noise_train_dataset, batch_size = 64, shuffle = True,generator = generator1)
noise_val_dataloader = DataLoader(noise_val_dataset, batch_size = 64, shuffle = True,generator = generator1)
raw_test_dataloader = DataLoader(raw_test_dataset, batch_size = 64, shuffle = True,generator = generator1)

# %% [markdown]
# # Train

# %% [markdown]
# ## Use different devices on Colab

# %%
# GPU
if torch.cuda.is_available():
    device = "cuda"
    # show GPU details
    # !nvidia-smi
else:
    device = "cpu"

print(f"\nUsing {device}")
# Out:
# Tue Aug 20 09:28:41 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   74C    P0              30W /  70W |    215MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+
#
# Using cuda

# %%
model0 = LeNet5().to(device)
# overview of model - enter the input size
summary(model0,(1,32,32),device = device)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#        BatchNorm2d-2            [-1, 6, 28, 28]              12
#               ReLU-3            [-1, 6, 28, 28]               0
#          MaxPool2d-4            [-1, 6, 14, 14]               0
#             Conv2d-5           [-1, 16, 10, 10]           2,416
#        BatchNorm2d-6           [-1, 16, 10, 10]              32
#               ReLU-7           [-1, 16, 10, 10]               0
#          MaxPool2d-8             [-1, 16, 5, 5]               0
#             Linear-9                  [-1, 120]          48,120
#              ReLU-10                  [-1, 120]               0
#            Linear-11                   [-1, 84]          10,164
#              ReLU-12                   [-1, 84]               0
#            Linear-13                   [-1, 10]             850
# ================================================================
# Total params: 61,750
# Trainable params: 61,750
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0
# epoch: 1, time: 5.96
# training loss:  0.55, accuracy: 81.98
# validation loss:  0.21, accuracy: 93.10
#
# epoch: 6, time: 5.38
# training loss:  0.10, accuracy: 97.00
# validation loss:  0.13, accuracy: 96.04
#
# epoch: 11, time: 4.75
# training loss:  0.06, accuracy: 97.94
# validation loss:  0.12, accuracy: 96.82
#
# epoch: 16, time: 4.68
# training loss:  0.04, accuracy: 98.99
# validation loss:  0.08, accuracy: 97.96
#
# epoch: 21, time: 4.68
# training loss:  0.04, accuracy: 98.81
# validation loss:  0.12, accuracy: 96.34
#
# Early stop at epoch 23

# %%
for lr in lrs:
    print(f"lr = {lr}")
    plotter0(model02_dict[lr])
    print()
# Out:
# lr = 1e-05
# lr = 5e-05
# lr = 0.0001
# lr = 0.005

# %%
# model test w/o transform
# accuracy check taken from
# https://discuss.pytorch.org/t/how-to-find-test-accuracy-after-training/88962/3
for i, lr in enumerate(lrs):
    num_correct = 0
    num_samples = 0
    models02[i].eval()

    with torch.no_grad():
        for input,target in raw_test_dataloader:
            input,target = input.to(device),target.to(device)
            scores = models02[i](input)
            _, predictions = scores.max(1)
            num_correct +=  (predictions ==  target).sum()
            num_samples +=  predictions.size(0)

    accuracy=float(num_correct)/float(num_samples)*100
    print(f"lr={lr}")
    print(f'Got {num_correct}/{num_samples} with accuracy {accuracy:0.2f}\n')
# Out:
# lr=1e-05
# Got 9617/10000 with accuracy 96.17
#
# lr=5e-05
# Got 9898/10000 with accuracy 98.98
#
# lr=0.0001
# Got 9924/10000 with accuracy 99.24
#
# lr=0.005
# Got 9941/10000 with accuracy 99.41

# %%
# save
time_stamp=time.strftime("%Y%m%d-%H%M%S")
for i, model in enumerate(models02):
    file_name="model02_lr"+str(lrs[i]).replace(".","point")+"_"+str(time_stamp)
    torch.save(model.state_dict(), f'output/{file_name}.pt')
    print(f"saved model as '{file_name}.pt'")

torch.save(model02_dict, f'output/model12_dict_{time_stamp}.pt')
print(f"saved dictionary as 'model12_dict_{time_stamp}.pt'")
# Out:
# saved model as 'model02_lr1e-05_20240820-095221.pt'
# saved model as 'model02_lr5e-05_20240820-095221.pt'
# saved model as 'model02_lr0point0001_20240820-095221.pt'
# saved model as 'model02_lr0point005_20240820-095221.pt'
# saved dictionary as 'model12_dict_20240820-095221.pt'

# %% [markdown]
# ## Train w/ my loss

# %%
# same base loss for all training
# our hyperparameter is alpha - the scalar for the loss
alphas = [0.1,0.5,1,10,50,100]
base_loss_fn = nn.CrossEntropyLoss()

# %%
# train
model12_dict,models12=trainer(100,lrs,alphas,"nn.Linear",noise_train_dataloader,noise_val_dataloader)
# Out:
# training for lr = 1e-05
# training for alpha = 0.1
# epoch: 1, time: 5.22
# training loss (base/corr/combo):  2.29/0.06/2.30, accuracy: 16.16
# validation loss (base/corr/combo):  2.27/0.06/2.28, accuracy: 22.27
#
# epoch: 6, time: 5.11
# training loss (base/corr/combo):  1.92/0.03/1.92, accuracy: 55.24
# validation loss (base/corr/combo):  1.87/0.03/1.87, accuracy: 58.40
#
# epoch: 11, time: 5.00
# training loss (base/corr/combo):  2.27/0.02/3.35, accuracy: 14.60
# validation loss (base/corr/combo):  2.27/0.02/3.40, accuracy: 14.11
#
# Early stop at epoch 42
#
# training for alpha = 100
# epoch: 1, time: 5.32
# training loss (base/corr/combo):  2.32/0.05/7.79, accuracy: 9.30
# validation loss (base/corr/combo):  2.31/0.04/6.01, accuracy: 8.94
#
# epoch: 6, time: 5.35
# training loss (base/corr/combo):  2.31/0.03/4.84, accuracy: 8.75
# validation loss (base/corr/combo):  2.31/0.03/4.86, accuracy: 9.90
#
# epoch: 11, time: 5.21
# training loss (base/corr/combo):  2.31/0.02/4.49, accuracy: 10.01
# validation loss (base/corr/combo):  2.31/0.02/4.60, accuracy: 9.96
#
# epoch: 16, time: 5.23
# training loss (base/corr/combo):  2.30/0.02/4.45, accuracy: 11.12
# validation loss (base/corr/combo):  2.30/0.02/4.53, accuracy: 11.52
#
# epoch: 21, time: 5.88
# training loss (base/corr/combo):  2.30/0.02/4.43, accuracy: 11.89
# validation loss (base/corr/combo):  2.30/0.02/4.59, accuracy: 12.24
#
# epoch: 26, time: 6.63
# training loss (base/corr/combo):  2.30/0.02/4.41, accuracy: 12.59
# validation loss (base/corr/combo):  2.30/0.02/4.57, accuracy: 13.69
#
# epoch: 31, time: 6.44
# training loss (base/corr/combo):  2.29/0.02/4.51, accuracy: 14.07
# validation loss (base/corr/combo):  2.29/0.02/4.49, accuracy: 15.25
#
# epoch: 36, time: 6.59
# training loss (base/corr/combo):  2.29/0.02/4.42, accuracy: 15.45
# validation loss (base/corr/combo):  2.29/0.02/4.46, accuracy: 16.63
#
# epoch: 41, time: 6.38
# training loss (base/corr/combo):  2.28/0.02/4.37, accuracy: 16.35
# validation loss (base/corr/combo):  2.28/0.02/4.52, accuracy: 17.17
#
# Early stop at epoch 42
#
# training for lr = 5e-05
# training for alpha = 0.1
# epoch: 1, time: 6.93
# training loss (base/corr/combo):  2.20/0.05/2.20, accuracy: 31.53
# validation loss (base/corr/combo):  2.02/0.04/2.02, accuracy: 52.88
#
# epoch: 6, time: 6.13
# training loss (base/corr/combo):  0.49/0.02/0.50, accuracy: 88.36
# validation loss (base/corr/combo):  0.45/0.02/0.46, accuracy: 88.72
#
# epoch: 11, time: 5.54
# training loss (base/corr/combo):  0.27/0.02/0.27, accuracy: 92.72
# validation loss (base/corr/combo):  0.28/0.02/0.29, accuracy: 91.30
#
# epoch: 16, time: 5.38
# training loss (base/corr/combo):  0.20/0.02/0.20, accuracy: 94.25
# validation loss (base/corr/combo):  0.22/0.02/0.22, accuracy: 93.52
#
# epoch: 21, time: 5.37
# training loss (base/corr/combo):  0.16/0.02/0.16, accuracy: 95.32
# validation loss (base/corr/combo):  0.17/0.02/0.18, accuracy: 94.42
#
# epoch: 26, time: 5.47
# training loss (base/corr/combo):  0.14/0.02/0.14, accuracy: 96.00
# validation loss (base/corr/combo):  0.16/0.02/0.16, accuracy: 95.32
#
# epoch: 31, time: 5.83
# training loss (base/corr/combo):  0.12/0.02/0.12, accuracy: 96.64
# validation loss (base/corr/combo):  0.14/0.02/0.14, accuracy: 95.44
#
# epoch: 36, time: 5.53
# training loss (base/corr/combo):  0.10/0.02/0.11, accuracy: 96.96
# validation loss (base/corr/combo):  0.13/0.02/0.13, accuracy: 96.04
#
# epoch: 41, time: 5.33
# training loss (base/corr/combo):  0.09/0.02/0.09, accuracy: 97.28
# validation loss (base/corr/combo):  0.12/0.02/0.12, accuracy: 96.40
#
# epoch: 46, time: 5.19
# training loss (base/corr/combo):  0.09/0.02/0.09, accuracy: 97.32
# validation loss (base/corr/combo):  0.10/0.02/0.11, accuracy: 96.46
#
# epoch: 51, time: 5.23
# training loss (base/corr/combo):  0.08/0.02/0.08, accuracy: 97.48
# validation loss (base/corr/combo):  0.10/0.02/0.10, accuracy: 96.52
#
# epoch: 56, time: 5.21
# training loss (base/corr/combo):  0.08/0.02/0.08, accuracy: 97.53
# validation loss (base/corr/combo):  0.09/0.02/0.10, accuracy: 96.88
#
# epoch: 61, time: 5.14
# training loss (base/corr/combo):  0.07/0.02/0.07, accuracy: 97.88
# validation loss (base/corr/combo):  0.09/0.02/0.09, accuracy: 96.40
#
# epoch: 66, time: 5.03
# training loss (base/corr/combo):  0.06/0.02/0.06, accuracy: 98.07
# validation loss (base/corr/combo):  0.08/0.02/0.09, accuracy: 97.30
#
# epoch: 71, time: 4.99
# training loss (base/corr/combo):  0.06/0.02/0.06, accuracy: 98.01
# validation loss (base/corr/combo):  0.09/0.02/0.09, accuracy: 96.82
#
# epoch: 76, time: 4.96
# training loss (base/corr/combo):  0.06/0.02/0.06, accuracy: 98.14
# validation loss (base/corr/combo):  0.08/0.02/0.09, accuracy: 97.06
#
# epoch: 81, time: 4.95
# training loss (base/corr/combo):  0.05/0.02/0.06, accuracy: 98.28
# validation loss (base/corr/combo):  0.09/0.02/0.10, accuracy: 96.82
#
# Early stop at epoch 85
#
# training for alpha = 0.5
# epoch: 1, time: 4.95
# training loss (base/corr/combo):  2.16/0.04/2.18, accuracy: 36.62
# validation loss (base/corr/combo):  1.94/0.03/1.96, accuracy: 59.54
#
# epoch: 6, time: 4.93
# training loss (base/corr/combo):  0.45/0.02/0.46, accuracy: 89.32
# validation loss (base/corr/combo):  0.43/0.02/0.44, accuracy: 88.36
#
# epoch: 11, time: 4.94
# training loss (base/corr/combo):  0.26/0.02/0.27, accuracy: 92.66
# validation loss (base/corr/combo):  0.27/0.02/0.28, accuracy: 92.26
#
# epoch: 16, time: 4.94
# training loss (base/corr/combo):  0.20/0.02/0.21, accuracy: 94.17
# validation loss (base/corr/combo):  0.21/0.02/0.22, accuracy: 93.64
#
# epoch: 21, time: 5.26
# training loss (base/corr/combo):  0.16/0.02/0.17, accuracy: 95.28
# validation loss (base/corr/combo):  0.18/0.02/0.19, accuracy: 94.54
#
# epoch: 26, time: 5.31
# training loss (base/corr/combo):  0.13/0.02/0.14, accuracy: 95.98
# validation loss (base/corr/combo):  0.15/0.02/0.17, accuracy: 95.38
#
# epoch: 31, time: 5.62
# training loss (base/corr/combo):  0.11/0.02/0.12, accuracy: 96.54
# validation loss (base/corr/combo):  0.15/0.02/0.16, accuracy: 95.32
#
# epoch: 36, time: 5.93
# training loss (base/corr/combo):  0.11/0.02/0.12, accuracy: 96.82
# validation loss (base/corr/combo):  0.13/0.02/0.14, accuracy: 96.10
#
# epoch: 41, time: 6.37
# training loss (base/corr/combo):  0.09/0.02/0.10, accuracy: 97.24
# validation loss (base/corr/combo):  0.13/0.02/0.14, accuracy: 95.98
#
# epoch: 46, time: 6.67
# training loss (base/corr/combo):  0.09/0.02/0.10, accuracy: 97.35
# validation loss (base/corr/combo):  0.11/0.02/0.13, accuracy: 96.28
#
# epoch: 51, time: 6.58
# training loss (base/corr/combo):  0.08/0.02/0.09, accuracy: 97.67
# validation loss (base/corr/combo):  0.10/0.02/0.11, accuracy: 96.82
#
# epoch: 56, time: 6.29
# training loss (base/corr/combo):  0.07/0.02/0.08, accuracy: 97.74
# validation loss (base/corr/combo):  0.10/0.02/0.11, accuracy: 97.12
#
# epoch: 61, time: 5.70
# training loss (base/corr/combo):  0.07/0.02/0.08, accuracy: 97.95
# validation loss (base/corr/combo):  0.11/0.02/0.12, accuracy: 96.22
#
# epoch: 66, time: 5.31
# training loss (base/corr/combo):  0.07/0.02/0.08, accuracy: 97.82
# validation loss (base/corr/combo):  0.09/0.02/0.10, accuracy: 97.18
#
# Early stop at epoch 68
#
# training for alpha = 1
# epoch: 1, time: 5.41
# training loss (base/corr/combo):  2.19/0.04/2.23, accuracy: 22.64
# validation loss (base/corr/combo):  2.04/0.03/2.07, accuracy: 41.00
#
# epoch: 6, time: 5.77
# training loss (base/corr/combo):  0.45/0.02/0.47, accuracy: 89.16
# validation loss (base/corr/combo):  0.42/0.02/0.44, accuracy: 88.78
#
# epoch: 11, time: 5.34
# training loss (base/corr/combo):  0.25/0.02/0.28, accuracy: 93.16
# validation loss (base/corr/combo):  0.26/0.02/0.29, accuracy: 91.78
#
# epoch: 16, time: 4.82
# training loss (base/corr/combo):  0.19/0.02/0.21, accuracy: 94.88
# validation loss (base/corr/combo):  0.20/0.02/0.23, accuracy: 93.88
#
# epoch: 21, time: 5.05
# training loss (base/corr/combo):  0.16/0.02/0.18, accuracy: 95.51
# validation loss (base/corr/combo):  0.16/0.02/0.19, accuracy: 95.14
#
# epoch: 26, time: 5.50
# training loss (base/corr/combo):  0.13/0.02/0.15, accuracy: 96.18
# validation loss (base/corr/combo):  0.14/0.02/0.17, accuracy: 95.38
#
# epoch: 31, time: 5.82
# training loss (base/corr/combo):  0.11/0.02/0.13, accuracy: 96.62
# validation loss (base/corr/combo):  0.14/0.02/0.16, accuracy: 95.92
#
# epoch: 36, time: 6.62
# training loss (base/corr/combo):  0.10/0.02/0.12, accuracy: 97.28
# validation loss (base/corr/combo):  0.11/0.02/0.13, accuracy: 96.40
#
# epoch: 41, time: 6.63
# training loss (base/corr/combo):  0.09/0.02/0.11, accuracy: 97.23
# validation loss (base/corr/combo):  0.11/0.02/0.13, accuracy: 96.58
#
# epoch: 46, time: 6.63
# training loss (base/corr/combo):  0.08/0.02/0.10, accuracy: 97.79
# validation loss (base/corr/combo):  0.10/0.02/0.12, accuracy: 97.12
#
# epoch: 51, time: 6.21
# training loss (base/corr/combo):  0.07/0.02/0.09, accuracy: 97.80
# validation loss (base/corr/combo):  0.09/0.02/0.11, accuracy: 96.94
#
# epoch: 56, time: 5.49
# training loss (base/corr/combo):  0.07/0.02/0.09, accuracy: 98.00
# validation loss (base/corr/combo):  0.10/0.02/0.12, accuracy: 96.76
#
# epoch: 61, time: 5.42
# training loss (base/corr/combo):  0.06/0.02/0.08, accuracy: 98.16
# validation loss (base/corr/combo):  0.09/0.02/0.11, accuracy: 96.82
#
# epoch: 66, time: 5.40
# training loss (base/corr/combo):  0.06/0.02/0.08, accuracy: 98.34
# validation loss (base/corr/combo):  0.09/0.02/0.11, accuracy: 96.52
#
# epoch: 71, time: 5.34
# training loss (base/corr/combo):  0.06/0.02/0.08, accuracy: 98.15
# validation loss (base/corr/combo):  0.08/0.02/0.10, accuracy: 97.18
#
# epoch: 76, time: 5.08
# training loss (base/corr/combo):  0.05/0.02/0.07, accuracy: 98.51
# validation loss (base/corr/combo):  0.09/0.02/0.11, accuracy: 97.18
#
# epoch: 81, time: 4.96
# training loss (base/corr/combo):  0.05/0.02/0.07, accuracy: 98.62
# validation loss (base/corr/combo):  0.08/0.02/0.10, accuracy: 97.30
#
# epoch: 86, time: 4.96
# training loss (base/corr/combo):  0.05/0.02/0.07, accuracy: 98.31
# validation loss (base/corr/combo):  0.07/0.02/0.09, accuracy: 97.30
#
# Early stop at epoch 89
#
# training for alpha = 10
# epoch: 1, time: 5.36
# training loss (base/corr/combo):  2.30/0.05/2.75, accuracy: 9.17
# validation loss (base/corr/combo):  2.29/0.03/2.60, accuracy: 9.84
#
# epoch: 6, time: 5.40
# training loss (base/corr/combo):  2.06/0.02/2.28, accuracy: 53.24
# validation loss (base/corr/combo):  2.02/0.02/2.21, accuracy: 54.26
#
# epoch: 11, time: 5.58
# training loss (base/corr/combo):  1.11/0.02/1.32, accuracy: 75.08
# validation loss (base/corr/combo):  1.02/0.02/1.23, accuracy: 76.41
#
# epoch: 16, time: 5.66
# training loss (base/corr/combo):  0.53/0.02/0.73, accuracy: 86.21
# validation loss (base/corr/combo):  0.50/0.02/0.73, accuracy: 86.67
#
# epoch: 21, time: 5.67
# training loss (base/corr/combo):  0.36/0.02/0.57, accuracy: 89.86
# validation loss (base/corr/combo):  0.36/0.02/0.55, accuracy: 88.78
#
# epoch: 26, time: 5.83
# training loss (base/corr/combo):  0.29/0.02/0.50, accuracy: 91.34
# validation loss (base/corr/combo):  0.29/0.02/0.51, accuracy: 91.12
#
# epoch: 31, time: 5.91
# training loss (base/corr/combo):  0.24/0.02/0.44, accuracy: 92.56
# validation loss (base/corr/combo):  0.25/0.02/0.44, accuracy: 92.02
#
# epoch: 36, time: 5.95
# training loss (base/corr/combo):  0.20/0.02/0.41, accuracy: 93.98
# validation loss (base/corr/combo):  0.22/0.02/0.43, accuracy: 93.16
#
# epoch: 41, time: 6.03
# training loss (base/corr/combo):  0.18/0.02/0.39, accuracy: 94.53
# validation loss (base/corr/combo):  0.18/0.02/0.37, accuracy: 94.54
#
# epoch: 46, time: 6.17
# training loss (base/corr/combo):  0.15/0.02/0.37, accuracy: 95.28
# validation loss (base/corr/combo):  0.17/0.02/0.38, accuracy: 94.54
#
# epoch: 51, time: 6.22
# training loss (base/corr/combo):  0.14/0.02/0.34, accuracy: 95.51
# validation loss (base/corr/combo):  0.14/0.02/0.35, accuracy: 95.98
#
# epoch: 56, time: 6.17
# training loss (base/corr/combo):  0.12/0.02/0.33, accuracy: 96.11
# validation loss (base/corr/combo):  0.14/0.02/0.36, accuracy: 95.08
#
# epoch: 61, time: 6.20
# training loss (base/corr/combo):  0.11/0.02/0.31, accuracy: 96.59
# validation loss (base/corr/combo):  0.13/0.02/0.32, accuracy: 95.80
#
# epoch: 66, time: 6.19
# training loss (base/corr/combo):  0.10/0.02/0.31, accuracy: 96.70
# validation loss (base/corr/combo):  0.11/0.02/0.31, accuracy: 96.64
#
# epoch: 71, time: 6.21
# training loss (base/corr/combo):  0.09/0.02/0.30, accuracy: 97.10
# validation loss (base/corr/combo):  0.11/0.02/0.32, accuracy: 96.52
#
# Early stop at epoch 72
#
# training for alpha = 50
# epoch: 1, time: 5.59
# training loss (base/corr/combo):  2.31/0.04/4.06, accuracy: 12.47
# validation loss (base/corr/combo):  2.31/0.03/3.57, accuracy: 11.34
#
# epoch: 6, time: 5.57
# training loss (base/corr/combo):  2.26/0.02/3.35, accuracy: 17.55
# validation loss (base/corr/combo):  2.26/0.02/3.35, accuracy: 17.65
#
# epoch: 11, time: 5.47
# training loss (base/corr/combo):  2.19/0.02/3.23, accuracy: 32.18
# validation loss (base/corr/combo):  2.19/0.02/3.25, accuracy: 32.35
#
# epoch: 16, time: 5.38
# training loss (base/corr/combo):  2.06/0.02/3.07, accuracy: 50.35
# validation loss (base/corr/combo):  2.05/0.02/3.03, accuracy: 51.14
#
# epoch: 21, time: 5.28
# training loss (base/corr/combo):  1.81/0.02/2.89, accuracy: 62.06
# validation loss (base/corr/combo):  1.78/0.02/2.77, accuracy: 62.30
#
# epoch: 26, time: 5.28
# training loss (base/corr/combo):  1.38/0.02/2.39, accuracy: 69.99
# validation loss (base/corr/combo):  1.35/0.02/2.28, accuracy: 69.57
#
# epoch: 31, time: 5.40
# training loss (base/corr/combo):  0.92/0.02/1.90, accuracy: 80.08
# validation loss (base/corr/combo):  0.90/0.02/2.01, accuracy: 79.47
#
# epoch: 36, time: 5.96
# training loss (base/corr/combo):  0.62/0.02/1.65, accuracy: 85.22
# validation loss (base/corr/combo):  0.61/0.02/1.72, accuracy: 84.09
#
# epoch: 41, time: 6.64
# training loss (base/corr/combo):  0.46/0.02/1.53, accuracy: 88.28
# validation loss (base/corr/combo):  0.46/0.02/1.47, accuracy: 87.45
#
# epoch: 46, time: 6.63
# training loss (base/corr/combo):  0.38/0.02/1.40, accuracy: 89.43
# validation loss (base/corr/combo):  0.39/0.02/1.44, accuracy: 88.24
#
# epoch: 51, time: 6.60
# training loss (base/corr/combo):  0.32/0.02/1.42, accuracy: 90.77
# validation loss (base/corr/combo):  0.34/0.02/1.25, accuracy: 89.56
#
# epoch: 56, time: 7.40
# training loss (base/corr/combo):  0.29/0.02/1.31, accuracy: 91.56
# validation loss (base/corr/combo):  0.31/0.02/1.29, accuracy: 90.04
#
# epoch: 61, time: 7.19
# training loss (base/corr/combo):  0.26/0.02/1.27, accuracy: 92.04
# validation loss (base/corr/combo):  0.27/0.02/1.34, accuracy: 91.60
#
# Early stop at epoch 61
#
# training for alpha = 100
# epoch: 1, time: 8.10
# training loss (base/corr/combo):  2.31/0.04/6.16, accuracy: 8.47
# validation loss (base/corr/combo):  2.31/0.03/5.24, accuracy: 10.44
#
# epoch: 6, time: 6.73
# training loss (base/corr/combo):  2.29/0.02/4.51, accuracy: 12.59
# validation loss (base/corr/combo):  2.29/0.02/4.41, accuracy: 13.81
#
# epoch: 11, time: 7.34
# training loss (base/corr/combo):  2.26/0.02/4.37, accuracy: 17.03
# validation loss (base/corr/combo):  2.25/0.02/4.45, accuracy: 18.79
#
# epoch: 16, time: 6.67
# training loss (base/corr/combo):  2.21/0.02/4.26, accuracy: 22.59
# validation loss (base/corr/combo):  2.20/0.02/4.30, accuracy: 22.03
#
# epoch: 21, time: 6.45
# training loss (base/corr/combo):  2.13/0.02/4.04, accuracy: 34.39
# validation loss (base/corr/combo):  2.11/0.02/4.32, accuracy: 35.35
#
# epoch: 26, time: 5.79
# training loss (base/corr/combo):  2.02/0.02/4.05, accuracy: 44.76
# validation loss (base/corr/combo):  2.01/0.02/3.64, accuracy: 47.12
#
# epoch: 31, time: 6.19
# training loss (base/corr/combo):  1.90/0.02/3.89, accuracy: 51.80
# validation loss (base/corr/combo):  1.88/0.02/3.68, accuracy: 52.40
#
# epoch: 36, time: 5.77
# training loss (base/corr/combo):  1.73/0.02/3.56, accuracy: 60.84
# validation loss (base/corr/combo):  1.72/0.02/3.43, accuracy: 61.58
#
# epoch: 41, time: 5.88
# training loss (base/corr/combo):  1.50/0.02/3.42, accuracy: 68.48
# validation loss (base/corr/combo):  1.47/0.02/3.39, accuracy: 69.75
#
# epoch: 46, time: 5.96
# training loss (base/corr/combo):  1.18/0.02/3.09, accuracy: 74.45
# validation loss (base/corr/combo):  1.16/0.02/3.14, accuracy: 75.93
#
# epoch: 51, time: 5.73
# training loss (base/corr/combo):  0.91/0.02/2.91, accuracy: 78.33
# validation loss (base/corr/combo):  0.90/0.02/3.08, accuracy: 78.63
#
# epoch: 56, time: 6.07
# training loss (base/corr/combo):  0.71/0.02/2.69, accuracy: 82.24
# validation loss (base/corr/combo):  0.71/0.02/3.09, accuracy: 81.75
#
# epoch: 61, time: 6.66
# training loss (base/corr/combo):  0.58/0.02/2.56, accuracy: 84.62
# validation loss (base/corr/combo):  0.58/0.02/2.44, accuracy: 84.51
#
# epoch: 66, time: 6.53
# training loss (base/corr/combo):  0.50/0.02/2.52, accuracy: 86.60
# validation loss (base/corr/combo):  0.52/0.02/2.55, accuracy: 85.71
#
# epoch: 71, time: 5.91
# training loss (base/corr/combo):  0.44/0.02/2.56, accuracy: 88.36
# validation loss (base/corr/combo):  0.47/0.02/2.46, accuracy: 87.82
#
# epoch: 76, time: 5.35
# training loss (base/corr/combo):  0.38/0.02/2.50, accuracy: 90.32
# validation loss (base/corr/combo):  0.41/0.02/2.43, accuracy: 88.06
#
# epoch: 81, time: 5.36
# training loss (base/corr/combo):  0.34/0.02/2.45, accuracy: 90.58
# validation loss (base/corr/combo):  0.35/0.02/2.57, accuracy: 89.98
#
# epoch: 86, time: 5.42
# training loss (base/corr/combo):  0.32/0.02/2.32, accuracy: 91.43
# validation loss (base/corr/combo):  0.36/0.02/2.55, accuracy: 89.44
#
# epoch: 91, time: 5.40
# training loss (base/corr/combo):  0.31/0.02/2.17, accuracy: 91.58
# validation loss (base/corr/combo):  0.33/0.02/2.33, accuracy: 90.70
#
# epoch: 96, time: 5.78
# training loss (base/corr/combo):  0.28/0.02/2.09, accuracy: 92.37
# validation loss (base/corr/combo):  0.32/0.02/2.28, accuracy: 90.34
#
# training for lr = 0.0001
# training for alpha = 0.1
# epoch: 1, time: 6.58
# training loss (base/corr/combo):  1.98/0.04/1.99, accuracy: 46.72
# validation loss (base/corr/combo):  1.46/0.03/1.46, accuracy: 70.35
#
# epoch: 6, time: 6.72
# training loss (base/corr/combo):  0.28/0.02/0.28, accuracy: 92.31
# validation loss (base/corr/combo):  0.27/0.02/0.28, accuracy: 91.78
#
# epoch: 11, time: 6.28
# training loss (base/corr/combo):  0.17/0.02/0.17, accuracy: 95.18
# validation loss (base/corr/combo):  0.19/0.02/0.19, accuracy: 93.76
#
# epoch: 16, time: 5.69
# training loss (base/corr/combo):  0.12/0.02/0.12, accuracy: 96.14
# validation loss (base/corr/combo):  0.14/0.02/0.14, accuracy: 95.20
#
# epoch: 21, time: 5.67
# training loss (base/corr/combo):  0.10/0.02/0.10, accuracy: 96.92
# validation loss (base/corr/combo):  0.14/0.02/0.14, accuracy: 95.68
#
# epoch: 26, time: 5.70
# training loss (base/corr/combo):  0.08/0.02/0.08, accuracy: 97.44
# validation loss (base/corr/combo):  0.10/0.02/0.11, accuracy: 96.82
#
# epoch: 31, time: 5.68
# training loss (base/corr/combo):  0.08/0.02/0.08, accuracy: 97.88
# validation loss (base/corr/combo):  0.10/0.02/0.11, accuracy: 96.34
#
# epoch: 36, time: 5.71
# training loss (base/corr/combo):  0.07/0.02/0.07, accuracy: 97.76
# validation loss (base/corr/combo):  0.09/0.02/0.09, accuracy: 97.12
#
# epoch: 41, time: 5.61
# training loss (base/corr/combo):  0.06/0.02/0.06, accuracy: 98.09
# validation loss (base/corr/combo):  0.09/0.02/0.09, accuracy: 97.36
#
# epoch: 46, time: 5.39
# training loss (base/corr/combo):  0.06/0.02/0.06, accuracy: 98.21
# validation loss (base/corr/combo):  0.10/0.02/0.10, accuracy: 96.82
#
# epoch: 51, time: 5.33
# training loss (base/corr/combo):  0.05/0.02/0.05, accuracy: 98.46
# validation loss (base/corr/combo):  0.11/0.02/0.11, accuracy: 96.46
#
# epoch: 56, time: 5.18
# training loss (base/corr/combo):  0.04/0.02/0.05, accuracy: 98.56
# validation loss (base/corr/combo):  0.09/0.02/0.09, accuracy: 97.00
#
# Early stop at epoch 57
#
# training for alpha = 0.5
# epoch: 1, time: 5.05
# training loss (base/corr/combo):  2.05/0.04/2.07, accuracy: 47.49
# validation loss (base/corr/combo):  1.56/0.03/1.57, accuracy: 68.43
#
# epoch: 6, time: 4.97
# training loss (base/corr/combo):  0.26/0.02/0.27, accuracy: 92.70
# validation loss (base/corr/combo):  0.26/0.02/0.27, accuracy: 92.74
#
# epoch: 11, time: 4.96
# training loss (base/corr/combo):  0.17/0.02/0.18, accuracy: 95.15
# validation loss (base/corr/combo):  0.18/0.02/0.19, accuracy: 93.94
#
# epoch: 16, time: 4.97
# training loss (base/corr/combo):  0.13/0.02/0.14, accuracy: 96.14
# validation loss (base/corr/combo):  0.14/0.02/0.15, accuracy: 95.44
#
# epoch: 21, time: 4.96
# training loss (base/corr/combo):  0.10/0.02/0.11, accuracy: 96.94
# validation loss (base/corr/combo):  0.13/0.02/0.14, accuracy: 95.80
#
# epoch: 26, time: 5.01
# training loss (base/corr/combo):  0.09/0.02/0.10, accuracy: 97.13
# validation loss (base/corr/combo):  0.13/0.02/0.14, accuracy: 95.38
#
# epoch: 31, time: 4.99
# training loss (base/corr/combo):  0.08/0.02/0.09, accuracy: 97.52
# validation loss (base/corr/combo):  0.10/0.02/0.11, accuracy: 96.88
#
# epoch: 36, time: 4.95
# training loss (base/corr/combo):  0.07/0.02/0.08, accuracy: 97.64
# validation loss (base/corr/combo):  0.10/0.02/0.11, accuracy: 97.18
#
# epoch: 41, time: 5.00
# training loss (base/corr/combo):  0.06/0.02/0.07, accuracy: 98.12
# validation loss (base/corr/combo):  0.10/0.02/0.11, accuracy: 96.58
#
# epoch: 46, time: 4.99
# training loss (base/corr/combo):  0.06/0.02/0.07, accuracy: 98.27
# validation loss (base/corr/combo):  0.09/0.02/0.10, accuracy: 97.06
#
# epoch: 51, time: 4.95
# training loss (base/corr/combo):  0.05/0.02/0.06, accuracy: 98.33
# validation loss (base/corr/combo):  0.09/0.02/0.10, accuracy: 97.30
#
# epoch: 56, time: 4.99
# training loss (base/corr/combo):  0.05/0.02/0.06, accuracy: 98.43
# validation loss (base/corr/combo):  0.08/0.02/0.09, accuracy: 97.18
#
# epoch: 61, time: 5.37
# training loss (base/corr/combo):  0.05/0.02/0.06, accuracy: 98.55
# validation loss (base/corr/combo):  0.07/0.02/0.08, accuracy: 97.66
#
# epoch: 66, time: 5.46
# training loss (base/corr/combo):  0.04/0.02/0.05, accuracy: 98.62
# validation loss (base/corr/combo):  0.09/0.02/0.10, accuracy: 97.30
#
# epoch: 71, time: 5.39
# training loss (base/corr/combo):  0.04/0.02/0.05, accuracy: 98.99
# validation loss (base/corr/combo):  0.09/0.02/0.10, accuracy: 97.30
#
# Early stop at epoch 71
#
# training for alpha = 1
# epoch: 1, time: 6.60
# training loss (base/corr/combo):  2.07/0.04/2.11, accuracy: 38.14
# validation loss (base/corr/combo):  1.67/0.03/1.70, accuracy: 62.55
#
# epoch: 6, time: 6.42
# training loss (base/corr/combo):  0.28/0.02/0.30, accuracy: 92.42
# validation loss (base/corr/combo):  0.28/0.02/0.31, accuracy: 91.72
#
# epoch: 11, time: 5.93
# training loss (base/corr/combo):  0.17/0.02/0.19, accuracy: 95.15
# validation loss (base/corr/combo):  0.19/0.02/0.21, accuracy: 94.06
#
# epoch: 16, time: 5.40
# training loss (base/corr/combo):  0.13/0.02/0.15, accuracy: 96.21
# validation loss (base/corr/combo):  0.15/0.02/0.17, accuracy: 94.96
#
# epoch: 21, time: 5.36
# training loss (base/corr/combo):  0.10/0.02/0.12, accuracy: 96.95
# validation loss (base/corr/combo):  0.12/0.02/0.14, accuracy: 96.22
#
# epoch: 26, time: 5.45
# training loss (base/corr/combo):  0.08/0.02/0.10, accuracy: 97.34
# validation loss (base/corr/combo):  0.13/0.02/0.15, accuracy: 96.04
#
# epoch: 31, time: 5.52
# training loss (base/corr/combo):  0.08/0.02/0.10, accuracy: 97.42
# validation loss (base/corr/combo):  0.11/0.02/0.13, accuracy: 96.46
#
# epoch: 36, time: 6.16
# training loss (base/corr/combo):  0.07/0.02/0.09, accuracy: 98.09
# validation loss (base/corr/combo):  0.09/0.02/0.11, accuracy: 97.30
#
# epoch: 41, time: 6.58
# training loss (base/corr/combo):  0.06/0.02/0.08, accuracy: 98.30
# validation loss (base/corr/combo):  0.08/0.02/0.11, accuracy: 96.88
#
# epoch: 46, time: 5.99
# training loss (base/corr/combo):  0.06/0.02/0.08, accuracy: 98.09
# validation loss (base/corr/combo):  0.08/0.02/0.10, accuracy: 97.24
#
# epoch: 51, time: 6.01
# training loss (base/corr/combo):  0.05/0.02/0.07, accuracy: 98.52
# validation loss (base/corr/combo):  0.09/0.02/0.11, accuracy: 96.94
#
# epoch: 56, time: 6.15
# training loss (base/corr/combo):  0.04/0.02/0.07, accuracy: 98.70
# validation loss (base/corr/combo):  0.08/0.02/0.10, accuracy: 97.54
#
# epoch: 61, time: 6.11
# training loss (base/corr/combo):  0.04/0.02/0.06, accuracy: 98.62
# validation loss (base/corr/combo):  0.09/0.02/0.11, accuracy: 97.18
#
# epoch: 66, time: 6.11
# training loss (base/corr/combo):  0.04/0.02/0.06, accuracy: 98.68
# validation loss (base/corr/combo):  0.07/0.02/0.10, accuracy: 97.66
#
# epoch: 71, time: 6.08
# training loss (base/corr/combo):  0.04/0.02/0.06, accuracy: 98.78
# validation loss (base/corr/combo):  0.07/0.02/0.09, accuracy: 97.84
#
# epoch: 76, time: 6.04
# training loss (base/corr/combo):  0.04/0.02/0.06, accuracy: 98.85
# validation loss (base/corr/combo):  0.08/0.02/0.10, accuracy: 97.18
#
# Early stop at epoch 79
#
# training for alpha = 10
# epoch: 1, time: 4.98
# training loss (base/corr/combo):  2.27/0.03/2.61, accuracy: 18.25
# validation loss (base/corr/combo):  2.23/0.02/2.46, accuracy: 26.53
#
# epoch: 6, time: 4.98
# training loss (base/corr/combo):  0.75/0.02/0.96, accuracy: 83.26
# validation loss (base/corr/combo):  0.63/0.02/0.85, accuracy: 84.99
#
# epoch: 11, time: 4.94
# training loss (base/corr/combo):  0.30/0.02/0.51, accuracy: 91.49
# validation loss (base/corr/combo):  0.30/0.02/0.49, accuracy: 90.58
#
# epoch: 16, time: 4.92
# training loss (base/corr/combo):  0.21/0.02/0.42, accuracy: 93.54
# validation loss (base/corr/combo):  0.22/0.02/0.44, accuracy: 92.44
#
# epoch: 21, time: 5.00
# training loss (base/corr/combo):  0.16/0.02/0.36, accuracy: 95.25
# validation loss (base/corr/combo):  0.16/0.02/0.38, accuracy: 94.54
#
# epoch: 26, time: 4.92
# training loss (base/corr/combo):  0.12/0.02/0.34, accuracy: 96.04
# validation loss (base/corr/combo):  0.15/0.02/0.37, accuracy: 94.72
#
# epoch: 31, time: 5.43
# training loss (base/corr/combo):  0.11/0.02/0.32, accuracy: 96.72
# validation loss (base/corr/combo):  0.13/0.02/0.34, accuracy: 95.62
#
# epoch: 36, time: 6.25
# training loss (base/corr/combo):  0.09/0.02/0.30, accuracy: 97.28
# validation loss (base/corr/combo):  0.12/0.02/0.34, accuracy: 96.34
#
# epoch: 41, time: 6.45
# training loss (base/corr/combo):  0.08/0.02/0.30, accuracy: 97.32
# validation loss (base/corr/combo):  0.12/0.02/0.31, accuracy: 95.98
#
# epoch: 46, time: 6.57
# training loss (base/corr/combo):  0.07/0.02/0.28, accuracy: 97.68
# validation loss (base/corr/combo):  0.10/0.02/0.33, accuracy: 96.76
#
# epoch: 51, time: 5.81
# training loss (base/corr/combo):  0.07/0.02/0.27, accuracy: 97.91
# validation loss (base/corr/combo):  0.10/0.02/0.29, accuracy: 96.88
#
# epoch: 56, time: 5.43
# training loss (base/corr/combo):  0.06/0.02/0.28, accuracy: 98.01
# validation loss (base/corr/combo):  0.09/0.02/0.28, accuracy: 97.30
#
# epoch: 61, time: 5.32
# training loss (base/corr/combo):  0.05/0.02/0.27, accuracy: 98.30
# validation loss (base/corr/combo):  0.09/0.02/0.30, accuracy: 96.88
#
# epoch: 66, time: 5.39
# training loss (base/corr/combo):  0.05/0.02/0.26, accuracy: 98.33
# validation loss (base/corr/combo):  0.08/0.02/0.29, accuracy: 97.54
#
# epoch: 71, time: 6.05
# training loss (base/corr/combo):  0.05/0.02/0.25, accuracy: 98.46
# validation loss (base/corr/combo):  0.09/0.02/0.29, accuracy: 97.06
#
# epoch: 76, time: 5.89
# training loss (base/corr/combo):  0.04/0.02/0.25, accuracy: 98.55
# validation loss (base/corr/combo):  0.08/0.02/0.28, accuracy: 97.18
#
# Early stop at epoch 77
#
# training for alpha = 50
# epoch: 1, time: 5.10
# training loss (base/corr/combo):  2.32/0.03/3.81, accuracy: 7.86
# validation loss (base/corr/combo):  2.31/0.02/3.50, accuracy: 9.42
#
# epoch: 6, time: 5.63
# training loss (base/corr/combo):  2.17/0.02/3.23, accuracy: 33.31
# validation loss (base/corr/combo):  2.15/0.02/3.21, accuracy: 35.05
#
# epoch: 11, time: 6.30
# training loss (base/corr/combo):  1.76/0.02/2.79, accuracy: 56.62
# validation loss (base/corr/combo):  1.71/0.02/2.72, accuracy: 60.02
#
# epoch: 16, time: 5.86
# training loss (base/corr/combo):  0.92/0.02/1.95, accuracy: 78.20
# validation loss (base/corr/combo):  0.87/0.02/1.97, accuracy: 79.47
#
# epoch: 21, time: 5.92
# training loss (base/corr/combo):  0.51/0.02/1.55, accuracy: 87.16
# validation loss (base/corr/combo):  0.49/0.02/1.56, accuracy: 86.37
#
# epoch: 26, time: 5.81
# training loss (base/corr/combo):  0.37/0.02/1.41, accuracy: 89.76
# validation loss (base/corr/combo):  0.37/0.02/1.42, accuracy: 89.32
#
# epoch: 31, time: 5.88
# training loss (base/corr/combo):  0.30/0.02/1.36, accuracy: 90.71
# validation loss (base/corr/combo):  0.33/0.02/1.44, accuracy: 89.74
#
# epoch: 36, time: 5.80
# training loss (base/corr/combo):  0.25/0.02/1.29, accuracy: 92.69
# validation loss (base/corr/combo):  0.27/0.02/1.35, accuracy: 91.24
#
# epoch: 41, time: 5.68
# training loss (base/corr/combo):  0.21/0.02/1.30, accuracy: 93.65
# validation loss (base/corr/combo):  0.25/0.02/1.27, accuracy: 91.54
#
# epoch: 46, time: 5.67
# training loss (base/corr/combo):  0.19/0.02/1.24, accuracy: 94.34
# validation loss (base/corr/combo):  0.22/0.02/1.43, accuracy: 92.74
#
# epoch: 51, time: 5.08
# training loss (base/corr/combo):  0.16/0.02/1.22, accuracy: 95.16
# validation loss (base/corr/combo):  0.20/0.02/1.33, accuracy: 93.22
#
# epoch: 56, time: 4.66
# training loss (base/corr/combo):  0.15/0.02/1.22, accuracy: 95.62
# validation loss (base/corr/combo):  0.17/0.02/1.20, accuracy: 93.94
#
# epoch: 61, time: 4.55
# training loss (base/corr/combo):  0.13/0.02/1.20, accuracy: 95.86
# validation loss (base/corr/combo):  0.16/0.02/1.25, accuracy: 94.90
#
# epoch: 66, time: 4.97
# training loss (base/corr/combo):  0.12/0.02/1.14, accuracy: 96.29
# validation loss (base/corr/combo):  0.15/0.02/1.15, accuracy: 95.26
#
# epoch: 71, time: 5.00
# training loss (base/corr/combo):  0.11/0.02/1.17, accuracy: 96.80
# validation loss (base/corr/combo):  0.14/0.02/1.15, accuracy: 95.32
#
# Early stop at epoch 73
#
# training for alpha = 100
# epoch: 1, time: 5.50
# training loss (base/corr/combo):  2.32/0.03/5.08, accuracy: 10.15
# validation loss (base/corr/combo):  2.31/0.02/4.59, accuracy: 10.92
#
# epoch: 6, time: 5.54
# training loss (base/corr/combo):  2.28/0.02/4.25, accuracy: 12.74
# validation loss (base/corr/combo):  2.27/0.02/4.36, accuracy: 12.42
#
# epoch: 11, time: 5.65
# training loss (base/corr/combo):  2.24/0.02/4.22, accuracy: 23.10
# validation loss (base/corr/combo):  2.22/0.02/4.60, accuracy: 25.75
#
# epoch: 16, time: 5.76
# training loss (base/corr/combo):  2.19/0.02/4.00, accuracy: 25.89
# validation loss (base/corr/combo):  2.17/0.02/4.35, accuracy: 27.43
#
# epoch: 21, time: 5.92
# training loss (base/corr/combo):  2.06/0.02/4.21, accuracy: 38.30
# validation loss (base/corr/combo):  2.02/0.02/3.90, accuracy: 45.32
#
# epoch: 26, time: 5.91
# training loss (base/corr/combo):  1.82/0.02/3.71, accuracy: 53.98
# validation loss (base/corr/combo):  1.78/0.02/3.45, accuracy: 56.36
#
# epoch: 31, time: 6.11
# training loss (base/corr/combo):  1.18/0.02/3.30, accuracy: 69.44
# validation loss (base/corr/combo):  1.09/0.02/3.27, accuracy: 70.23
#
# epoch: 36, time: 6.13
# training loss (base/corr/combo):  0.73/0.02/2.73, accuracy: 78.53
# validation loss (base/corr/combo):  0.71/0.02/2.68, accuracy: 78.45
#
# epoch: 41, time: 6.18
# training loss (base/corr/combo):  0.52/0.02/2.60, accuracy: 84.87
# validation loss (base/corr/combo):  0.52/0.02/2.53, accuracy: 85.29
#
# epoch: 46, time: 6.05
# training loss (base/corr/combo):  0.40/0.02/2.54, accuracy: 88.34
# validation loss (base/corr/combo):  0.41/0.02/2.73, accuracy: 87.52
#
# epoch: 51, time: 6.04
# training loss (base/corr/combo):  0.34/0.02/2.29, accuracy: 90.54
# validation loss (base/corr/combo):  0.35/0.02/2.37, accuracy: 89.56
#
# epoch: 56, time: 6.19
# training loss (base/corr/combo):  0.29/0.02/2.28, accuracy: 91.67
# validation loss (base/corr/combo):  0.32/0.02/2.36, accuracy: 90.70
#
# Early stop at epoch 57
#
# training for lr = 0.005
# training for alpha = 0.1
# epoch: 1, time: 5.09
# training loss (base/corr/combo):  0.46/0.02/0.47, accuracy: 85.25
# validation loss (base/corr/combo):  0.24/0.02/0.24, accuracy: 92.38
#
# epoch: 6, time: 5.07
# training loss (base/corr/combo):  0.09/0.02/0.09, accuracy: 97.14
# validation loss (base/corr/combo):  0.09/0.02/0.09, accuracy: 97.12
#
# epoch: 11, time: 4.94
# training loss (base/corr/combo):  0.06/0.02/0.06, accuracy: 98.16
# validation loss (base/corr/combo):  0.16/0.02/0.16, accuracy: 95.80
#
# epoch: 16, time: 5.00
# training loss (base/corr/combo):  0.04/0.02/0.04, accuracy: 98.78
# validation loss (base/corr/combo):  0.13/0.02/0.13, accuracy: 96.52
#
# epoch: 21, time: 5.12
# training loss (base/corr/combo):  0.04/0.02/0.04, accuracy: 98.69
# validation loss (base/corr/combo):  0.12/0.02/0.12, accuracy: 96.82
#
# Early stop at epoch 24
#
# training for alpha = 0.5
# epoch: 1, time: 5.01
# training loss (base/corr/combo):  0.50/0.02/0.52, accuracy: 83.56
# validation loss (base/corr/combo):  0.21/0.02/0.22, accuracy: 93.64
#
# epoch: 6, time: 4.99
# training loss (base/corr/combo):  0.08/0.02/0.09, accuracy: 97.38
# validation loss (base/corr/combo):  0.13/0.02/0.14, accuracy: 96.16
#
# epoch: 11, time: 5.08
# training loss (base/corr/combo):  0.05/0.02/0.06, accuracy: 98.31
# validation loss (base/corr/combo):  0.12/0.02/0.13, accuracy: 97.00
#
# epoch: 16, time: 5.02
# training loss (base/corr/combo):  0.05/0.02/0.06, accuracy: 98.49
# validation loss (base/corr/combo):  0.21/0.02/0.22, accuracy: 94.24
#
# epoch: 21, time: 5.00
# training loss (base/corr/combo):  0.03/0.02/0.04, accuracy: 98.97
# validation loss (base/corr/combo):  0.09/0.02/0.10, accuracy: 97.54
#
# epoch: 26, time: 5.02
# training loss (base/corr/combo):  0.03/0.02/0.04, accuracy: 99.00
# validation loss (base/corr/combo):  0.10/0.02/0.11, accuracy: 97.60
#
# Early stop at epoch 29
#
# training for alpha = 1
# epoch: 1, time: 6.15
# training loss (base/corr/combo):  0.49/0.02/0.52, accuracy: 83.99
# validation loss (base/corr/combo):  0.31/0.02/0.34, accuracy: 89.20
#
# epoch: 6, time: 6.06
# training loss (base/corr/combo):  0.07/0.02/0.09, accuracy: 97.65
# validation loss (base/corr/combo):  0.11/0.02/0.13, accuracy: 96.94
#
# epoch: 11, time: 6.01
# training loss (base/corr/combo):  0.04/0.02/0.06, accuracy: 98.74
# validation loss (base/corr/combo):  0.13/0.02/0.15, accuracy: 96.82
#
# epoch: 16, time: 6.11
# training loss (base/corr/combo):  0.04/0.02/0.06, accuracy: 98.51
# validation loss (base/corr/combo):  0.11/0.02/0.13, accuracy: 96.82
#
# epoch: 21, time: 6.11
# training loss (base/corr/combo):  0.03/0.02/0.05, accuracy: 99.06
# validation loss (base/corr/combo):  0.09/0.02/0.12, accuracy: 97.18
#
# epoch: 26, time: 6.09
# training loss (base/corr/combo):  0.03/0.02/0.05, accuracy: 99.16
# validation loss (base/corr/combo):  0.09/0.02/0.11, accuracy: 97.84
#
# Early stop at epoch 28
#
# training for alpha = 10
# epoch: 1, time: 5.83
# training loss (base/corr/combo):  0.84/0.03/1.13, accuracy: 72.08
# validation loss (base/corr/combo):  0.28/0.02/0.48, accuracy: 90.28
#
# epoch: 6, time: 5.32
# training loss (base/corr/combo):  0.09/0.02/0.28, accuracy: 97.38
# validation loss (base/corr/combo):  0.18/0.02/0.39, accuracy: 94.30
#
# epoch: 11, time: 5.25
# training loss (base/corr/combo):  0.05/0.02/0.25, accuracy: 98.18
# validation loss (base/corr/combo):  0.09/0.02/0.28, accuracy: 97.90
#
# epoch: 16, time: 5.36
# training loss (base/corr/combo):  0.05/0.02/0.24, accuracy: 98.31
# validation loss (base/corr/combo):  0.07/0.02/0.26, accuracy: 97.84
#
# epoch: 21, time: 5.51
# training loss (base/corr/combo):  0.04/0.02/0.23, accuracy: 98.45
# validation loss (base/corr/combo):  0.11/0.02/0.32, accuracy: 97.06
#
# epoch: 26, time: 6.18
# training loss (base/corr/combo):  0.04/0.02/0.22, accuracy: 98.85
# validation loss (base/corr/combo):  0.09/0.02/0.28, accuracy: 97.42
#
# epoch: 31, time: 6.58
# training loss (base/corr/combo):  0.04/0.02/0.22, accuracy: 98.80
# validation loss (base/corr/combo):  0.10/0.02/0.27, accuracy: 97.00
#
# epoch: 36, time: 6.59
# training loss (base/corr/combo):  0.04/0.02/0.24, accuracy: 98.92
# validation loss (base/corr/combo):  0.07/0.02/0.29, accuracy: 98.08
#
# Early stop at epoch 37
#
# training for alpha = 50
# epoch: 1, time: 6.56
# training loss (base/corr/combo):  1.31/0.02/2.49, accuracy: 54.70
# validation loss (base/corr/combo):  0.57/0.02/1.64, accuracy: 80.55
#
# epoch: 6, time: 6.60
# training loss (base/corr/combo):  0.17/0.02/1.13, accuracy: 94.97
# validation loss (base/corr/combo):  0.17/0.02/1.19, accuracy: 94.42
#
# epoch: 11, time: 6.08
# training loss (base/corr/combo):  0.10/0.02/1.10, accuracy: 96.83
# validation loss (base/corr/combo):  0.17/0.02/1.23, accuracy: 95.62
#
# epoch: 16, time: 5.40
# training loss (base/corr/combo):  0.11/0.02/1.09, accuracy: 96.99
# validation loss (base/corr/combo):  0.23/0.02/1.13, accuracy: 94.60
#
# epoch: 21, time: 5.36
# training loss (base/corr/combo):  0.07/0.02/0.97, accuracy: 98.06
# validation loss (base/corr/combo):  0.31/0.02/1.17, accuracy: 94.90
#
# Early stop at epoch 23
#
# training for alpha = 100
# epoch: 1, time: 4.96
# training loss (base/corr/combo):  1.64/0.03/4.24, accuracy: 46.22
# validation loss (base/corr/combo):  0.76/0.02/2.90, accuracy: 75.21
#
# epoch: 6, time: 4.94
# training loss (base/corr/combo):  0.19/0.02/2.21, accuracy: 93.94
# validation loss (base/corr/combo):  0.25/0.02/2.32, accuracy: 92.02
#
# epoch: 11, time: 5.03
# training loss (base/corr/combo):  0.16/0.02/1.84, accuracy: 95.28
# validation loss (base/corr/combo):  0.18/0.02/1.91, accuracy: 94.78
#
# epoch: 16, time: 5.02
# training loss (base/corr/combo):  0.16/0.02/1.99, accuracy: 96.14
# validation loss (base/corr/combo):  0.16/0.02/2.28, accuracy: 95.38
#
# epoch: 21, time: 4.92
# training loss (base/corr/combo):  0.10/0.02/1.91, accuracy: 96.94
# validation loss (base/corr/combo):  0.12/0.02/1.91, accuracy: 96.82
#
# Early stop at epoch 22

# %%
# save
time_stamp=time.strftime("%Y%m%d-%H%M%S")
for i, lr_models in enumerate(models12):
    for j,model in enumerate(lr_models):
        file_name="model12_lr"+str(lrs[i]).replace(".","point")+"_alpha"+str(alphas[j]).replace(".","point")+"_"+str(time_stamp)
        torch.save(model.state_dict(), f'output/{file_name}.pt')
        print(f"saved model as '{file_name}.pt'")

torch.save(model12_dict, f'output/model12_dict_{time_stamp}.pt')
print(f"saved dictionary as 'model12_dict_{time_stamp}.pt'")
# Out:
# saved model as 'model12_lr1e-05_alpha0point1_20240820-121629.pt'
# saved model as 'model12_lr1e-05_alpha0point5_20240820-121629.pt'
# saved model as 'model12_lr1e-05_alpha1_20240820-121629.pt'
# saved model as 'model12_lr1e-05_alpha10_20240820-121629.pt'
# saved model as 'model12_lr1e-05_alpha50_20240820-121629.pt'
# saved model as 'model12_lr1e-05_alpha100_20240820-121629.pt'
# saved model as 'model12_lr5e-05_alpha0point1_20240820-121629.pt'
# saved model as 'model12_lr5e-05_alpha0point5_20240820-121629.pt'
# saved model as 'model12_lr5e-05_alpha1_20240820-121629.pt'
# saved model as 'model12_lr5e-05_alpha10_20240820-121629.pt'
# saved model as 'model12_lr5e-05_alpha50_20240820-121629.pt'
# saved model as 'model12_lr5e-05_alpha100_20240820-121629.pt'
# saved model as 'model12_lr0point0001_alpha0point1_20240820-121629.pt'
# saved model as 'model12_lr0point0001_alpha0point5_20240820-121629.pt'
# saved model as 'model12_lr0point0001_alpha1_20240820-121629.pt'
# saved model as 'model12_lr0point0001_alpha10_20240820-121629.pt'
# saved model as 'model12_lr0point0001_alpha50_20240820-121629.pt'
# saved model as 'model12_lr0point0001_alpha100_20240820-121629.pt'
# saved model as 'model12_lr0point005_alpha0point1_20240820-121629.pt'
# saved model as 'model12_lr0point005_alpha0point5_20240820-121629.pt'
# saved model as 'model12_lr0point005_alpha1_20240820-121629.pt'
# saved model as 'model12_lr0point005_alpha10_20240820-121629.pt'
# saved model as 'model12_lr0point005_alpha50_20240820-121629.pt'
# saved model as 'model12_lr0point005_alpha100_20240820-121629.pt'
# saved dictionary as 'model12_dict_20240820-121629.pt'

# %%
# plot training metrics
for lr in lrs:
    print(f"Learning rate = {lr}")
    plotter(alphas,model12_dict[lr],scaler=10)
# Out:
# Learning rate = 1e-05
# Learning rate = 5e-05
# Learning rate = 0.0001
# Learning rate = 0.005

# %%
# plot training metrics
for lr in lrs:
    print(f"Learning rate = {lr}")
    plotter_corr(alphas,model12_dict[lr])
# Out:
# Learning rate = 1e-05
# Learning rate = 5e-05
# Learning rate = 0.0001
# Learning rate = 0.005

# %%
for i,lr in enumerate(lrs):
    print(f"lr = {lr}")
    # accuracy on test set - raw images
    tester(models12[i],alphas,raw_test_dataloader,"raw")
# Out:
# lr = 1e-05
# Alpha = 0.1 Model:
# Got 9670/10000 with accuracy 96.70
#
# Alpha = 0.5 Model:
# Got 9645/10000 with accuracy 96.45
#
# Alpha = 1 Model:
# Got 9602/10000 with accuracy 96.02
#
# Alpha = 10 Model:
# Got 9319/10000 with accuracy 93.19
#
# Alpha = 50 Model:
# Got 1084/10000 with accuracy 10.84
#
# Alpha = 100 Model:
# Got 1597/10000 with accuracy 15.97
#
# lr = 5e-05
# Alpha = 0.1 Model:
# Got 9909/10000 with accuracy 99.09
#
# Alpha = 0.5 Model:
# Got 9875/10000 with accuracy 98.75
#
# Alpha = 1 Model:
# Got 9919/10000 with accuracy 99.19
#
# Alpha = 10 Model:
# Got 9790/10000 with accuracy 97.90
#
# Alpha = 50 Model:
# Got 9279/10000 with accuracy 92.79
#
# Alpha = 100 Model:
# Got 9401/10000 with accuracy 94.01
#
# lr = 0.0001
# Alpha = 0.1 Model:
# Got 9932/10000 with accuracy 99.32
#
# Alpha = 0.5 Model:
# Got 9944/10000 with accuracy 99.44
#
# Alpha = 1 Model:
# Got 9950/10000 with accuracy 99.50
#
# Alpha = 10 Model:
# Got 9921/10000 with accuracy 99.21
#
# Alpha = 50 Model:
# Got 9718/10000 with accuracy 97.18
#
# Alpha = 100 Model:
# Got 9078/10000 with accuracy 90.78
#
# lr = 0.005
# Alpha = 0.1 Model:
# Got 9937/10000 with accuracy 99.37
#
# Alpha = 0.5 Model:
# Got 9966/10000 with accuracy 99.66
#
# Alpha = 1 Model:
# Got 9969/10000 with accuracy 99.69
#
# Alpha = 10 Model:
# Got 9962/10000 with accuracy 99.62
#
# Alpha = 50 Model:
# Got 9855/10000 with accuracy 98.55
#
# Alpha = 100 Model:
# Got 9705/10000 with accuracy 97.05
